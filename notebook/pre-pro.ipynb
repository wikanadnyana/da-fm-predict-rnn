# %%
import pandas as pd
import os

# %%
df = pd.read_csv("D:\SMT 6 Project\Data Analytics\model-rnn\data\match.csv")

# %%
df
# Out:
#       Unnamed: 0        date   time            comp         round  day venue
# 0              1  2022-08-07  16:30  Premier League   Matchweek 1  Sun  Away  \
# 1              2  2022-08-13  15:00  Premier League   Matchweek 2  Sat  Home
# 2              3  2022-08-21  16:30  Premier League   Matchweek 3  Sun  Away
# 3              4  2022-08-27  15:00  Premier League   Matchweek 4  Sat  Home
# 4              5  2022-08-31  19:30  Premier League   Matchweek 5  Wed  Home
# ...          ...         ...    ...             ...           ...  ...   ...
# 4489          38  2018-04-15  16:00  Premier League  Matchweek 34  Sun  Away
# 4490          39  2018-04-21  12:30  Premier League  Matchweek 35  Sat  Home
# 4491          40  2018-04-28  15:00  Premier League  Matchweek 36  Sat  Away
# 4492          41  2018-05-05  15:00  Premier League  Matchweek 37  Sat  Home
# 4493          42  2018-05-13  15:00  Premier League  Matchweek 38  Sun  Away
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4494 entries, 0 to 4493
# Data columns (total 28 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    4494 non-null   int64
#  1   date          4494 non-null   object
#  2   time          4494 non-null   object
#  3   comp          4494 non-null   object
#  4   round         4494 non-null   object
#  5   day           4494 non-null   object
#  6   venue         4494 non-null   object
#  7   result        4494 non-null   object
#  8   gf            4494 non-null   float64
#  9   ga            4494 non-null   float64
#  10  opponent      4494 non-null   object
#  11  xg            4494 non-null   float64
#  12  xga           4494 non-null   float64
#  13  poss          4494 non-null   float64
#  14  attendance    3614 non-null   float64
#  15  captain       4494 non-null   object
#  16  formation     4494 non-null   object
#  17  referee       4494 non-null   object
# ...

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4494 entries, 0 to 4493
# Data columns (total 28 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    4494 non-null   int64
#  1   date          4494 non-null   datetime64[ns]
#  2   time          4494 non-null   object
#  3   comp          4494 non-null   object
#  4   round         4494 non-null   object
#  5   day           4494 non-null   object
#  6   venue         4494 non-null   object
#  7   result        4494 non-null   object
#  8   gf            4494 non-null   float64
#  9   ga            4494 non-null   float64
#  10  opponent      4494 non-null   object
#  11  xg            4494 non-null   float64
#  12  xga           4494 non-null   float64
#  13  poss          4494 non-null   float64
#  14  attendance    3614 non-null   float64
#  15  captain       4494 non-null   object
#  16  formation     4494 non-null   object
# ...

# %%
df_clean = df.loc[:, ['date', 'team', 'opponent', 'gf', 'ga']]

# %%
df_clean
# Out:
#            date                  team         opponent   gf   ga
# 0    2022-08-07       Manchester City         West Ham  2.0  0.0
# 1    2022-08-13       Manchester City      Bournemouth  4.0  0.0
# 2    2022-08-21       Manchester City    Newcastle Utd  3.0  3.0
# 3    2022-08-27       Manchester City   Crystal Palace  4.0  2.0
# 4    2022-08-31       Manchester City  Nott'ham Forest  6.0  0.0
# ...         ...                   ...              ...  ...  ...
# 4489 2018-04-15  West Bromwich Albion   Manchester Utd  1.0  0.0
# 4490 2018-04-21  West Bromwich Albion        Liverpool  2.0  2.0
# 4491 2018-04-28  West Bromwich Albion    Newcastle Utd  1.0  0.0
# 4492 2018-05-05  West Bromwich Albion        Tottenham  1.0  0.0
# 4493 2018-05-13  West Bromwich Albion   Crystal Palace  0.0  2.0
#
# [4494 rows x 5 columns]

# %%
df_clean = df_clean.sort_values('date')
df_clean
# Out:
#            date                      team         opponent   gf   ga
# 3924 2017-08-11                   Arsenal   Leicester City  4.0  3.0
# 4038 2017-08-11            Leicester City          Arsenal  3.0  4.0
# 3734 2017-08-12           Manchester City         Brighton  2.0  0.0
# 4418 2017-08-12                Stoke City          Everton  0.0  1.0
# 4266 2017-08-12  Brighton and Hove Albion  Manchester City  0.0  2.0
# ...         ...                       ...              ...  ...  ...
# 344  2023-05-08                    Fulham   Leicester City  5.0  3.0
# 693  2023-05-08               Southampton  Nott'ham Forest  3.0  4.0
# 623  2023-05-08            Leicester City           Fulham  3.0  5.0
# 588  2023-05-08                   Everton         Brighton  5.0  1.0
# 553  2023-05-08         Nottingham Forest      Southampton  4.0  3.0
#
# [4494 rows x 5 columns]

# %%
df_clean.duplicated().value_counts()
# Out:
# False    4494
# Name: count, dtype: int64

# %%
df_clean.to_csv('D:\SMT 6 Project\Data Analytics\model-rnn\data\match-clean.csv', index=False)
